# %%
import tensorflow as tf
import numpy as np
import os
import glob
import scipy.misc
import scipy.ndimage

def prepare_data(sess, folderpath):
  """
  Args:
    dataset: choose train dataset or test dataset
    For train dataset, output data would be ['.../t1.bmp', '.../t2.bmp', ..., '.../t99.bmp']
  """
  filetype = 'jpg'
  # filenames = os.listdir(folderpath)
  # print filenames
  print folderpath
  data = glob.glob(os.path.join(folderpath, "*.%s" % (filetype)))
  print data
  return data

def preprocess(path, config):
  """
  Preprocess single image file 
    (1) Read original image as YCbCr format (and grayscale as default)
    (2) Normalize
    (3) Apply image file with bicubic interpolation
  Args:
    path: file path of desired file
    input_: image applied bicubic interpolation (low-resolution)
    label_: image with original resolution (high-resolution)
  """

  _input = scipy.misc.imread(path, flatten=True, mode='YCbCr').astype(np.float)
  _label = 1
  return _input, _label
  #label_ = modcrop(image, scale)
  
  return input_, label_
def input_setup(sess, config):
    data = prepare_data(sess, 'Data/Images/CUHK')
    for i in xrange(len(data)):
        input_, label_ = preprocess(data[i], config)
        print input_, label_

# %%
scipy.misc.imread?

# %%
i = scipy.misc.imread('Data/Images/CUHK/f-005-01.jpg', flatten=True, mode='L').astype(np.float)

# %%
i.shape
# Out:
# (768, 1024)

# %%
image = scipy.misc.imread('Cropped/Data/Images/Caucasian/Front/CF0001_2201_00F.jpg', flatten=True, mode='L').astype(np.float)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image.shape
size = image.shape[0]

# %%
sub = int(math.floor(np.mod(image.shape[0], 64) / 2.0))
print image[sub:size-sub, sub:size-sub].shape
scale = image[sub:size-sub, sub:size-sub].shape[0]
print scale
print scale / 64
1./1
# Out:
# (65, 65)
# 65
# 1
# 1.0

# %%
sub = np.mod(image.shape[0], 64)
sub2 = sub/2
scale = image[sub2:310-sub2, sub2:310-sub2].shape[0] / 64
input_ = scipy.ndimage.interpolation.zoom(image[sub2:310-sub2, sub2:310-sub2], (1./scale), prefilter=False)
input_.shape
#plt.imsave('face3.jpg', input_)

# %%
cv2.COLOR

# %%
scale = image[sub2:310-sub2, sub2:310-sub2].shape[0] / 64

# %%
input_ = scipy.ndimage.interpolation.zoom(image[sub2:310-sub2, sub2:310-sub2], (1./scale), prefilter=False)

# %%
input_.shape
# Out:
# (64, 64)

# %%
plt.imsave('face3.jpg', input_)

# %%
plt.imshow(image[sub2:310-sub2, sub2:310-sub2])

# %%
image = image[0:min(image.shape),:min(image.shape)]

# %%
import dlib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-82a137582d6f> in <module>()
# ----> 1 import dlib
#
# ImportError: No module named dlib

# %%
import cv2
import sys

# Get user supplied values
imagePath = 'Data/Images/CUHK/f-005-01.jpg'
cascPath = "haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

crop_img = image[y: y + h, x: x + w]
cv2.imwrite("face.jpg", crop_img)
# Out:
# Found 1 faces!
# True

# %%
input_array = [
    [1,2,3],
    [2,3,4],
    [3,4,5]
]

# %%
print input_array
mean_image = np.mean(input_array, axis=0)
print mean_image
input_array -= mean_image
print input_array
# Out:
# [[1, 2, 3], [2, 3, 4], [3, 4, 5]]
# [ 2.  3.  4.]
# [[-1. -1. -1.]
#  [ 0.  0.  0.]
#  [ 1.  1.  1.]]

# %%
import math

# %%
np.mod(111, 64)
int(math.ceil(47/2.0))
scale = newImage[to_crop:size-to_crop, to_crop:size-to_crop].shape[0] / dsize
# Out:
# 24

# %%
gender = panda.

# %%
61440 / 18816.0
# Out:
# 3.2653061224489797
